# %%
import dataset
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
dataset.DatasetChirping()

loader = torch.utils.data.DataLoader(, batch_size=4, shuffle=True, num_workers=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\dsart\OneDrive\Desktop\Projects\MLGW\testing.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dsart/OneDrive/Desktop/Projects/MLGW/testing.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> loader = torch.utils.data.DataLoader(dataset.DatasetChirping(), batch_size=4, shuffle=True, num_workers=2)
#
# TypeError: DatasetChirping.__init__() missing 2 required positional arguments: 'n_measurements' and 'sampling_period'

# %%
# Number of sample points
N = 10000
# sample spacing
T = 1.0 / 10000.0

frequencies, psds = np.loadtxt("LIGOL_noise.txt", dtype="double", unpack=True)
noise_signal = noise.generate(T, N, colour=noise.LIGOL())

yf = np.fft.fft(noise_signal)
xf = np.fft.fftfreq(N, T)[: N // 2]
plt.loglog(xf, 2.0 / N * np.abs(yf[0 : N // 2]))
plt.loglog(frequencies, psds)

plt.grid()
plt.show()
plt.plot(noise_signal)
